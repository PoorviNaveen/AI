# %%
# ---------------------------------------------------------
# Resolution Theorem Prover with Step-by-Step Trace
# ---------------------------------------------------------

import itertools

def is_variable(token):
    return token[0].islower()

def parse_literal(lit):
    neg = lit.startswith("~")
    if neg:
        lit = lit[1:]
    pred = lit.split("(")[0]
    args = lit.split("(")[1][:-1].split(",")
    args = tuple(a.strip() for a in args)
    return (pred, args, neg)

def negate(lit):
    pred, args, neg = lit
    return (pred, args, not neg)

def substitute(term, theta):
    if is_variable(term) and term in theta:
        return substitute(theta[term], theta)
    return term

def apply_substitution(literal, theta):
    pred, args, neg = literal
    new_args = tuple(substitute(a, theta) for a in args)
    return (pred, new_args, neg)

def unify_terms(a, b, theta):
    a = substitute(a, theta)
    b = substitute(b, theta)

    if a == b:
        return theta
    if is_variable(a):
        theta[a] = b
        return theta
    if is_variable(b):
        theta[b] = a
        return theta
    return None

def unify_literals(l1, l2):
    pred1, args1, neg1 = l1
    pred2, args2, neg2 = l2

    if pred1 != pred2:
        return None
    if neg1 == neg2:
        return None
    if len(args1) != len(args2):
        return None

    theta = {}

    for a, b in zip(args1, args2):
        theta = unify_terms(a, b, theta)
        if theta is None:
            return None

    return theta

def resolve(c1, c2):
    resolvents = []
    for lit1 in c1:
        for lit2 in c2:
            theta = unify_literals(lit1, lit2)
            if theta is not None:
                new_clause = set()

                for l in c1:
                    if l != lit1:
                        new_clause.add(apply_substitution(l, theta))
                for l in c2:
                    if l != lit2:
                        new_clause.add(apply_substitution(l, theta))

                resolvents.append(frozenset(new_clause))

    return resolvents

def pretty_clause(cl):
    if len(cl) == 0:
        return "{}"
    def lit_to_str(l):
        pred, args, neg = l
        return ("~" if neg else "") + pred + "(" + ",".join(args) + ")"
    return "{ " + ", ".join(lit_to_str(l) for l in cl) + " }"

# ---------------------------------------------------------
# Knowledge base clauses (CNF)
# ---------------------------------------------------------

clauses = [
    # 1. John likes all food -> ¬Food(x) ∨ Likes(John,x)
    frozenset([("Food", ("x",), True), ("Likes", ("John","x"), False)]),

    # 2. Apple, Vegetables are food
    frozenset([("Food", ("Apple",), False)]),
    frozenset([("Food", ("Vegetables",), False)]),

    # 3. Eats(x,y) ∧ ¬Killed(x) -> Food(y)
    frozenset([("Killed", ("x",), False), ("Eats",("x","y"), True), ("Food",("y",), False)]),

    # 4. Anil eats peanuts, Anil alive
    frozenset([("Eats", ("Anil","Peanuts"), False)]),
    frozenset([("Alive", ("Anil",), False)]),

    # 5. ∀y (Eats(Anil,y) -> Eats(Harry,y))
    frozenset([("Eats",("Anil","y"), True), ("Eats",("Harry","y"), False)]),

    # 6. Alive(x) → ¬Killed(x)
    frozenset([("Alive",("x",), True), ("Killed",("x",), True)]),

    # 7. ¬Killed(x) → Alive(x)
    frozenset([("Killed",("x",), False), ("Alive",("x",), False)]),

    # Negated goal: ¬Likes(John, Peanuts)
    frozenset([("Likes", ("John","Peanuts"), True)])
]

# ---------------------------------------------------------
# Resolution loop
# ---------------------------------------------------------

def resolution(clauses):
    new = set()
    iteration = 1

    while True:
        pairs = list(itertools.combinations(clauses, 2))

        for (ci, cj) in pairs:
            resolvents = resolve(ci, cj)

            for r in resolvents:
                print(f"Iteration {iteration}: Resolving")
                print("  ", pretty_clause(ci))
                print("  ", pretty_clause(cj))
                print("  =>", pretty_clause(r), "\n")

                if len(r) == 0:
                    print("❌ Empty clause derived — PROOF COMPLETE!")
                    return True

                new.add(r)
                iteration += 1

        if new.issubset(set(clauses)):
            print("No new clauses. Resolution ends with failure.")
            return False

        for c in new:
            clauses.append(c)


resolution(clauses)
# Out:
# Iteration 1: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Apple) }
#   => { Likes(John,Apple) }
#
# Iteration 2: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Vegetables) }
#   => { Likes(John,Vegetables) }
#
# Iteration 3: Resolving
#    { Likes(John,x), ~Food(x) }
#    { ~Eats(x,y), Killed(x), Food(y) }
#   => { ~Eats(y,y), Killed(y), Likes(John,y) }
#
# Iteration 4: Resolving
#    { Likes(John,x), ~Food(x) }
#    { ~Likes(John,Peanuts) }
#   => { ~Food(Peanuts) }
#
# Iteration 5: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { Eats(Anil,Peanuts) }
#   => { Food(Peanuts), Killed(Anil) }
#
# Iteration 6: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { Eats(Harry,y), ~Eats(Anil,y) }
#   => { Food(y), ~Eats(Anil,y), Killed(Harry) }
#
# Iteration 7: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { ~Alive(x), ~Killed(x) }
#   => { ~Eats(x,y), ~Alive(x), Food(y) }
#
# Iteration 8: Resolving
#    { Eats(Anil,Peanuts) }
#    { Eats(Harry,y), ~Eats(Anil,y) }
#   => { Eats(Harry,Peanuts) }
#
# Iteration 9: Resolving
#    { Alive(Anil) }
#    { ~Alive(x), ~Killed(x) }
#   => { ~Killed(Anil) }
#
# Iteration 10: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Alive(x), Killed(x) }
#   => { Killed(x), ~Killed(x) }
#
# Iteration 11: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Alive(x), Killed(x) }
#   => { Alive(x), ~Alive(x) }
#
# Iteration 12: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Apple) }
#   => { Likes(John,Apple) }
#
# Iteration 13: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Vegetables) }
#   => { Likes(John,Vegetables) }
#
# Iteration 14: Resolving
#    { Likes(John,x), ~Food(x) }
#    { ~Eats(x,y), Killed(x), Food(y) }
#   => { ~Eats(y,y), Killed(y), Likes(John,y) }
#
# Iteration 15: Resolving
#    { Likes(John,x), ~Food(x) }
#    { ~Likes(John,Peanuts) }
#   => { ~Food(Peanuts) }
#
# Iteration 16: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Peanuts), Killed(Anil) }
#   => { Likes(John,Peanuts), Killed(Anil) }
#
# Iteration 17: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#   => { Killed(Harry), ~Eats(Anil,y), Likes(John,y) }
#
# Iteration 18: Resolving
#    { Likes(John,x), ~Food(x) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { ~Eats(y,y), ~Alive(y), Likes(John,y) }
#
# Iteration 19: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { Eats(Anil,Peanuts) }
#   => { Food(Peanuts), Killed(Anil) }
#
# Iteration 20: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { Eats(Harry,y), ~Eats(Anil,y) }
#   => { Food(y), ~Eats(Anil,y), Killed(Harry) }
#
# Iteration 21: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { ~Alive(x), ~Killed(x) }
#   => { ~Eats(x,y), ~Alive(x), Food(y) }
#
# Iteration 22: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { ~Killed(Anil) }
#   => { Food(y), ~Eats(Anil,y) }
#
# Iteration 23: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { Killed(x), ~Killed(x) }
#   => { ~Eats(x,y), Killed(x), Food(y) }
#
# Iteration 24: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { Eats(Harry,Peanuts) }
#   => { Food(Peanuts), Killed(Harry) }
#
# Iteration 25: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { ~Food(Peanuts) }
#   => { Killed(x), ~Eats(x,Peanuts) }
#
# Iteration 26: Resolving
#    { Eats(Anil,Peanuts) }
#    { Eats(Harry,y), ~Eats(Anil,y) }
#   => { Eats(Harry,Peanuts) }
#
# Iteration 27: Resolving
#    { Eats(Anil,Peanuts) }
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#   => { Food(Peanuts), Killed(Harry) }
#
# Iteration 28: Resolving
#    { Eats(Anil,Peanuts) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { Food(Peanuts), ~Alive(Anil) }
#
# Iteration 29: Resolving
#    { Alive(Anil) }
#    { ~Alive(x), ~Killed(x) }
#   => { ~Killed(Anil) }
#
# Iteration 30: Resolving
#    { Alive(Anil) }
#    { Alive(x), ~Alive(x) }
#   => { Alive(Anil) }
#
# Iteration 31: Resolving
#    { Alive(Anil) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { Food(y), ~Eats(Anil,y) }
#
# Iteration 32: Resolving
#    { Eats(Harry,y), ~Eats(Anil,y) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { Food(y), ~Alive(Harry), ~Eats(Anil,y) }
#
# Iteration 33: Resolving
#    { Eats(Harry,y), ~Eats(Anil,y) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { Likes(John,Harry), ~Eats(Anil,Harry), Killed(Harry) }
#
# Iteration 34: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Alive(x), Killed(x) }
#   => { Killed(x), ~Killed(x) }
#
# Iteration 35: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Alive(x), Killed(x) }
#   => { Alive(x), ~Alive(x) }
#
# Iteration 36: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Food(Peanuts), Killed(Anil) }
#   => { Food(Peanuts), ~Alive(Anil) }
#
# Iteration 37: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Alive(x), ~Alive(x) }
#   => { ~Alive(x), ~Killed(x) }
#
# Iteration 38: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#   => { ~Eats(Anil,y), Food(y), ~Alive(Harry) }
#
# Iteration 39: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Killed(x), ~Killed(x) }
#   => { ~Alive(x), ~Killed(x) }
#
# Iteration 40: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { ~Eats(y,y), ~Alive(y), Likes(John,y) }
#
# Iteration 41: Resolving
#    { Alive(x), Killed(x) }
#    { Alive(x), ~Alive(x) }
#   => { Alive(x), Killed(x) }
#
# Iteration 42: Resolving
#    { Alive(x), Killed(x) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { ~Eats(x,y), Killed(x), Food(y) }
#
# Iteration 43: Resolving
#    { Alive(x), Killed(x) }
#    { ~Killed(Anil) }
#   => { Alive(Anil) }
#
# Iteration 44: Resolving
#    { Alive(x), Killed(x) }
#    { Killed(x), ~Killed(x) }
#   => { Alive(x), Killed(x) }
#
# Iteration 45: Resolving
#    { ~Likes(John,Peanuts) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { ~Eats(Peanuts,Peanuts), Killed(Peanuts) }
#
# Iteration 46: Resolving
#    { Food(Peanuts), Killed(Anil) }
#    { ~Killed(Anil) }
#   => { Food(Peanuts) }
#
# Iteration 47: Resolving
#    { Food(Peanuts), Killed(Anil) }
#    { Killed(x), ~Killed(x) }
#   => { Food(Peanuts), Killed(Anil) }
#
# Iteration 48: Resolving
#    { Food(Peanuts), Killed(Anil) }
#    { ~Food(Peanuts) }
#   => { Killed(Anil) }
#
# Iteration 49: Resolving
#    { Alive(x), ~Alive(x) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { ~Eats(x,y), ~Alive(x), Food(y) }
#
# Iteration 50: Resolving
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#    { Killed(x), ~Killed(x) }
#   => { Food(y), ~Eats(Anil,y), Killed(Harry) }
#
# Iteration 51: Resolving
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#    { ~Food(Peanuts) }
#   => { ~Eats(Anil,Peanuts), Killed(Harry) }
#
# Iteration 52: Resolving
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#    { Eats(Harry,Peanuts) }
#   => { Food(Peanuts), ~Alive(Harry) }
#
# Iteration 53: Resolving
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#    { ~Food(Peanuts) }
#   => { ~Alive(x), ~Eats(x,Peanuts) }
#
# Iteration 54: Resolving
#    { ~Killed(Anil) }
#    { Killed(x), ~Killed(x) }
#   => { ~Killed(Anil) }
#
# Iteration 55: Resolving
#    { ~Killed(Anil) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { ~Eats(Anil,Anil), Likes(John,Anil) }
#
# Iteration 56: Resolving
#    { Killed(x), ~Killed(x) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { ~Eats(y,y), Killed(y), Likes(John,y) }
#
# Iteration 57: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Apple) }
#   => { Likes(John,Apple) }
#
# Iteration 58: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Vegetables) }
#   => { Likes(John,Vegetables) }
#
# Iteration 59: Resolving
#    { Likes(John,x), ~Food(x) }
#    { ~Eats(x,y), Killed(x), Food(y) }
#   => { ~Eats(y,y), Killed(y), Likes(John,y) }
#
# Iteration 60: Resolving
#    { Likes(John,x), ~Food(x) }
#    { ~Likes(John,Peanuts) }
#   => { ~Food(Peanuts) }
#
# Iteration 61: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Peanuts), Killed(Anil) }
#   => { Likes(John,Peanuts), Killed(Anil) }
#
# Iteration 62: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#   => { Killed(Harry), ~Eats(Anil,y), Likes(John,y) }
#
# Iteration 63: Resolving
#    { Likes(John,x), ~Food(x) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { ~Eats(y,y), ~Alive(y), Likes(John,y) }
#
# Iteration 64: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Peanuts), Killed(Harry) }
#   => { Likes(John,Peanuts), Killed(Harry) }
#
# Iteration 65: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(y), ~Eats(Anil,y) }
#   => { ~Eats(Anil,y), Likes(John,y) }
#
# Iteration 66: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#   => { Killed(Harry), ~Eats(Anil,y), Likes(John,y) }
#
# Iteration 67: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Peanuts), Killed(Anil) }
#   => { Likes(John,Peanuts), Killed(Anil) }
#
# Iteration 68: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Peanuts) }
#   => { Likes(John,Peanuts) }
#
# Iteration 69: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(y), ~Alive(Harry), ~Eats(Anil,y) }
#   => { ~Eats(Anil,y), ~Alive(Harry), Likes(John,y) }
#
# Iteration 70: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Peanuts), ~Alive(Anil) }
#   => { Likes(John,Peanuts), ~Alive(Anil) }
#
# Iteration 71: Resolving
#    { Likes(John,x), ~Food(x) }
#    { Food(Peanuts), ~Alive(Harry) }
#   => { Likes(John,Peanuts), ~Alive(Harry) }
#
# Iteration 72: Resolving
#    { Likes(John,x), ~Food(x) }
#    { ~Eats(x,y), Killed(x), Food(y) }
#   => { ~Eats(y,y), Killed(y), Likes(John,y) }
#
# Iteration 73: Resolving
#    { Likes(John,x), ~Food(x) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { ~Eats(y,y), ~Alive(y), Likes(John,y) }
#
# Iteration 74: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { Eats(Anil,Peanuts) }
#   => { Food(Peanuts), Killed(Anil) }
#
# Iteration 75: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { Eats(Harry,y), ~Eats(Anil,y) }
#   => { Food(y), ~Eats(Anil,y), Killed(Harry) }
#
# Iteration 76: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { ~Alive(x), ~Killed(x) }
#   => { ~Eats(x,y), ~Alive(x), Food(y) }
#
# Iteration 77: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { ~Killed(Anil) }
#   => { Food(y), ~Eats(Anil,y) }
#
# Iteration 78: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { Killed(x), ~Killed(x) }
#   => { ~Eats(x,y), Killed(x), Food(y) }
#
# Iteration 79: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { Eats(Harry,Peanuts) }
#   => { Food(Peanuts), Killed(Harry) }
#
# Iteration 80: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { ~Food(Peanuts) }
#   => { Killed(x), ~Eats(x,Peanuts) }
#
# Iteration 81: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { ~Alive(x), ~Killed(x) }
#   => { ~Eats(x,y), ~Alive(x), Food(y) }
#
# Iteration 82: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { Eats(Harry,Peanuts) }
#   => { Food(Peanuts), Killed(Harry) }
#
# Iteration 83: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { Killed(x), ~Killed(x) }
#   => { ~Eats(x,y), Killed(x), Food(y) }
#
# Iteration 84: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { ~Killed(Anil) }
#   => { Food(y), ~Eats(Anil,y) }
#
# Iteration 85: Resolving
#    { ~Eats(x,y), Killed(x), Food(y) }
#    { ~Food(Peanuts) }
#   => { Killed(x), ~Eats(x,Peanuts) }
#
# Iteration 86: Resolving
#    { Eats(Anil,Peanuts) }
#    { Eats(Harry,y), ~Eats(Anil,y) }
#   => { Eats(Harry,Peanuts) }
#
# Iteration 87: Resolving
#    { Eats(Anil,Peanuts) }
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#   => { Food(Peanuts), Killed(Harry) }
#
# Iteration 88: Resolving
#    { Eats(Anil,Peanuts) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { Food(Peanuts), ~Alive(Anil) }
#
# Iteration 89: Resolving
#    { Eats(Anil,Peanuts) }
#    { Food(y), ~Eats(Anil,y) }
#   => { Food(Peanuts) }
#
# Iteration 90: Resolving
#    { Eats(Anil,Peanuts) }
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#   => { Food(Peanuts), Killed(Harry) }
#
# Iteration 91: Resolving
#    { Eats(Anil,Peanuts) }
#    { ~Eats(Anil,Peanuts), Killed(Harry) }
#   => { Killed(Harry) }
#
# Iteration 92: Resolving
#    { Eats(Anil,Peanuts) }
#    { Killed(x), ~Eats(x,Peanuts) }
#   => { Killed(Anil) }
#
# Iteration 93: Resolving
#    { Eats(Anil,Peanuts) }
#    { Food(y), ~Alive(Harry), ~Eats(Anil,y) }
#   => { Food(Peanuts), ~Alive(Harry) }
#
# Iteration 94: Resolving
#    { Eats(Anil,Peanuts) }
#    { ~Alive(x), ~Eats(x,Peanuts) }
#   => { ~Alive(Anil) }
#
# Iteration 95: Resolving
#    { Eats(Anil,Peanuts) }
#    { Killed(Harry), ~Eats(Anil,y), Likes(John,y) }
#   => { Likes(John,Peanuts), Killed(Harry) }
#
# Iteration 96: Resolving
#    { Eats(Anil,Peanuts) }
#    { ~Eats(x,y), Killed(x), Food(y) }
#   => { Food(Peanuts), Killed(Anil) }
#
# Iteration 97: Resolving
#    { Eats(Anil,Peanuts) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { Food(Peanuts), ~Alive(Anil) }
#
# Iteration 98: Resolving
#    { Alive(Anil) }
#    { ~Alive(x), ~Killed(x) }
#   => { ~Killed(Anil) }
#
# Iteration 99: Resolving
#    { Alive(Anil) }
#    { Alive(x), ~Alive(x) }
#   => { Alive(Anil) }
#
# Iteration 100: Resolving
#    { Alive(Anil) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { Food(y), ~Eats(Anil,y) }
#
# Iteration 101: Resolving
#    { Alive(Anil) }
#    { ~Alive(x), ~Killed(x) }
#   => { ~Killed(Anil) }
#
# Iteration 102: Resolving
#    { Alive(Anil) }
#    { Food(Peanuts), ~Alive(Anil) }
#   => { Food(Peanuts) }
#
# Iteration 103: Resolving
#    { Alive(Anil) }
#    { ~Eats(y,y), ~Alive(y), Likes(John,y) }
#   => { ~Eats(Anil,Anil), Likes(John,Anil) }
#
# Iteration 104: Resolving
#    { Alive(Anil) }
#    { ~Alive(x), ~Eats(x,Peanuts) }
#   => { ~Eats(Anil,Peanuts) }
#
# Iteration 105: Resolving
#    { Alive(Anil) }
#    { Alive(x), ~Alive(x) }
#   => { Alive(Anil) }
#
# Iteration 106: Resolving
#    { Alive(Anil) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { Food(y), ~Eats(Anil,y) }
#
# Iteration 107: Resolving
#    { Eats(Harry,y), ~Eats(Anil,y) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { Food(y), ~Alive(Harry), ~Eats(Anil,y) }
#
# Iteration 108: Resolving
#    { Eats(Harry,y), ~Eats(Anil,y) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { Likes(John,Harry), ~Eats(Anil,Harry), Killed(Harry) }
#
# Iteration 109: Resolving
#    { Eats(Harry,y), ~Eats(Anil,y) }
#    { Killed(x), ~Eats(x,Peanuts) }
#   => { ~Eats(Anil,Peanuts), Killed(Harry) }
#
# Iteration 110: Resolving
#    { Eats(Harry,y), ~Eats(Anil,y) }
#    { ~Eats(y,y), ~Alive(y), Likes(John,y) }
#   => { Likes(John,Harry), ~Alive(Harry), ~Eats(Anil,Harry) }
#
# Iteration 111: Resolving
#    { Eats(Harry,y), ~Eats(Anil,y) }
#    { ~Alive(x), ~Eats(x,Peanuts) }
#   => { ~Eats(Anil,Peanuts), ~Alive(Harry) }
#
# Iteration 112: Resolving
#    { Eats(Harry,y), ~Eats(Anil,y) }
#    { ~Eats(x,y), Killed(x), Food(y) }
#   => { Food(y), ~Eats(Anil,y), Killed(Harry) }
#
# Iteration 113: Resolving
#    { Eats(Harry,y), ~Eats(Anil,y) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { Likes(John,Harry), ~Eats(Anil,Harry), Killed(Harry) }
#
# Iteration 114: Resolving
#    { Eats(Harry,y), ~Eats(Anil,y) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { Food(y), ~Alive(Harry), ~Eats(Anil,y) }
#
# Iteration 115: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Alive(x), Killed(x) }
#   => { Killed(x), ~Killed(x) }
#
# Iteration 116: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Alive(x), Killed(x) }
#   => { Alive(x), ~Alive(x) }
#
# Iteration 117: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Food(Peanuts), Killed(Anil) }
#   => { Food(Peanuts), ~Alive(Anil) }
#
# Iteration 118: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Alive(x), ~Alive(x) }
#   => { ~Alive(x), ~Killed(x) }
#
# Iteration 119: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#   => { ~Eats(Anil,y), Food(y), ~Alive(Harry) }
#
# Iteration 120: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Killed(x), ~Killed(x) }
#   => { ~Alive(x), ~Killed(x) }
#
# Iteration 121: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { ~Eats(y,y), ~Alive(y), Likes(John,y) }
#
# Iteration 122: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Food(Peanuts), Killed(Harry) }
#   => { Food(Peanuts), ~Alive(Harry) }
#
# Iteration 123: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#   => { ~Eats(Anil,y), Food(y), ~Alive(Harry) }
#
# Iteration 124: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Likes(John,Peanuts), Killed(Anil) }
#   => { Likes(John,Peanuts), ~Alive(Anil) }
#
# Iteration 125: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { ~Eats(Anil,Peanuts), Killed(Harry) }
#   => { ~Eats(Anil,Peanuts), ~Alive(Harry) }
#
# Iteration 126: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Food(Peanuts), Killed(Anil) }
#   => { Food(Peanuts), ~Alive(Anil) }
#
# Iteration 127: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Killed(x), ~Eats(x,Peanuts) }
#   => { ~Alive(x), ~Eats(x,Peanuts) }
#
# Iteration 128: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Likes(John,Harry), ~Eats(Anil,Harry), Killed(Harry) }
#   => { Likes(John,Harry), ~Eats(Anil,Harry), ~Alive(Harry) }
#
# Iteration 129: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Killed(x), ~Killed(x) }
#   => { ~Alive(x), ~Killed(x) }
#
# Iteration 130: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Alive(x), Killed(x) }
#   => { Killed(x), ~Killed(x) }
#
# Iteration 131: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Alive(x), Killed(x) }
#   => { Alive(x), ~Alive(x) }
#
# Iteration 132: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Killed(Harry), ~Eats(Anil,y), Likes(John,y) }
#   => { ~Eats(Anil,y), ~Alive(Harry), Likes(John,y) }
#
# Iteration 133: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Alive(Anil) }
#   => { ~Killed(Anil) }
#
# Iteration 134: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { ~Eats(x,y), Killed(x), Food(y) }
#   => { ~Eats(x,y), ~Alive(x), Food(y) }
#
# Iteration 135: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { ~Eats(y,y), ~Alive(y), Likes(John,y) }
#
# Iteration 136: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Killed(Anil) }
#   => { ~Alive(Anil) }
#
# Iteration 137: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { ~Eats(Peanuts,Peanuts), Killed(Peanuts) }
#   => { ~Eats(Peanuts,Peanuts), ~Alive(Peanuts) }
#
# Iteration 138: Resolving
#    { ~Alive(x), ~Killed(x) }
#    { Alive(x), ~Alive(x) }
#   => { ~Alive(x), ~Killed(x) }
#
# Iteration 139: Resolving
#    { Alive(x), Killed(x) }
#    { Alive(x), ~Alive(x) }
#   => { Alive(x), Killed(x) }
#
# Iteration 140: Resolving
#    { Alive(x), Killed(x) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { ~Eats(x,y), Killed(x), Food(y) }
#
# Iteration 141: Resolving
#    { Alive(x), Killed(x) }
#    { ~Killed(Anil) }
#   => { Alive(Anil) }
#
# Iteration 142: Resolving
#    { Alive(x), Killed(x) }
#    { Killed(x), ~Killed(x) }
#   => { Alive(x), Killed(x) }
#
# Iteration 143: Resolving
#    { Alive(x), Killed(x) }
#    { ~Alive(x), ~Killed(x) }
#   => { Killed(x), ~Killed(x) }
#
# Iteration 144: Resolving
#    { Alive(x), Killed(x) }
#    { ~Alive(x), ~Killed(x) }
#   => { Alive(x), ~Alive(x) }
#
# Iteration 145: Resolving
#    { Alive(x), Killed(x) }
#    { Food(y), ~Alive(Harry), ~Eats(Anil,y) }
#   => { Food(y), ~Eats(Anil,y), Killed(Harry) }
#
# Iteration 146: Resolving
#    { Alive(x), Killed(x) }
#    { Food(Peanuts), ~Alive(Anil) }
#   => { Food(Peanuts), Killed(Anil) }
#
# Iteration 147: Resolving
#    { Alive(x), Killed(x) }
#    { ~Eats(y,y), ~Alive(y), Likes(John,y) }
#   => { ~Eats(y,y), Killed(y), Likes(John,y) }
#
# Iteration 148: Resolving
#    { Alive(x), Killed(x) }
#    { Food(Peanuts), ~Alive(Harry) }
#   => { Food(Peanuts), Killed(Harry) }
#
# Iteration 149: Resolving
#    { Alive(x), Killed(x) }
#    { Killed(x), ~Killed(x) }
#   => { Alive(x), Killed(x) }
#
# Iteration 150: Resolving
#    { Alive(x), Killed(x) }
#    { ~Alive(x), ~Eats(x,Peanuts) }
#   => { Killed(x), ~Eats(x,Peanuts) }
#
# Iteration 151: Resolving
#    { Alive(x), Killed(x) }
#    { Alive(x), ~Alive(x) }
#   => { Alive(x), Killed(x) }
#
# Iteration 152: Resolving
#    { Alive(x), Killed(x) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { ~Eats(x,y), Killed(x), Food(y) }
#
# Iteration 153: Resolving
#    { Alive(x), Killed(x) }
#    { ~Killed(Anil) }
#   => { Alive(Anil) }
#
# Iteration 154: Resolving
#    { ~Likes(John,Peanuts) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { ~Eats(Peanuts,Peanuts), Killed(Peanuts) }
#
# Iteration 155: Resolving
#    { ~Likes(John,Peanuts) }
#    { Likes(John,Peanuts), Killed(Anil) }
#   => { Killed(Anil) }
#
# Iteration 156: Resolving
#    { ~Likes(John,Peanuts) }
#    { ~Eats(y,y), ~Alive(y), Likes(John,y) }
#   => { ~Eats(Peanuts,Peanuts), ~Alive(Peanuts) }
#
# Iteration 157: Resolving
#    { ~Likes(John,Peanuts) }
#    { Killed(Harry), ~Eats(Anil,y), Likes(John,y) }
#   => { ~Eats(Anil,Peanuts), Killed(Harry) }
#
# Iteration 158: Resolving
#    { ~Likes(John,Peanuts) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { ~Eats(Peanuts,Peanuts), Killed(Peanuts) }
#
# Iteration 159: Resolving
#    { Food(Peanuts), Killed(Anil) }
#    { ~Killed(Anil) }
#   => { Food(Peanuts) }
#
# Iteration 160: Resolving
#    { Food(Peanuts), Killed(Anil) }
#    { Killed(x), ~Killed(x) }
#   => { Food(Peanuts), Killed(Anil) }
#
# Iteration 161: Resolving
#    { Food(Peanuts), Killed(Anil) }
#    { ~Food(Peanuts) }
#   => { Killed(Anil) }
#
# Iteration 162: Resolving
#    { Food(Peanuts), Killed(Anil) }
#    { ~Alive(x), ~Killed(x) }
#   => { Food(Peanuts), ~Alive(Anil) }
#
# Iteration 163: Resolving
#    { Food(Peanuts), Killed(Anil) }
#    { Killed(x), ~Killed(x) }
#   => { Food(Peanuts), Killed(Anil) }
#
# Iteration 164: Resolving
#    { Food(Peanuts), Killed(Anil) }
#    { ~Killed(Anil) }
#   => { Food(Peanuts) }
#
# Iteration 165: Resolving
#    { Food(Peanuts), Killed(Anil) }
#    { ~Food(Peanuts) }
#   => { Killed(Anil) }
#
# Iteration 166: Resolving
#    { Alive(x), ~Alive(x) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { ~Eats(x,y), ~Alive(x), Food(y) }
#
# Iteration 167: Resolving
#    { Alive(x), ~Alive(x) }
#    { ~Alive(x), ~Killed(x) }
#   => { ~Alive(x), ~Killed(x) }
#
# Iteration 168: Resolving
#    { Alive(x), ~Alive(x) }
#    { Food(y), ~Alive(Harry), ~Eats(Anil,y) }
#   => { ~Eats(Anil,y), Food(y), ~Alive(Harry) }
#
# Iteration 169: Resolving
#    { Alive(x), ~Alive(x) }
#    { Food(Peanuts), ~Alive(Anil) }
#   => { Food(Peanuts), ~Alive(Anil) }
#
# Iteration 170: Resolving
#    { Alive(x), ~Alive(x) }
#    { ~Eats(y,y), ~Alive(y), Likes(John,y) }
#   => { ~Eats(y,y), ~Alive(y), Likes(John,y) }
#
# Iteration 171: Resolving
#    { Alive(x), ~Alive(x) }
#    { Food(Peanuts), ~Alive(Harry) }
#   => { Food(Peanuts), ~Alive(Harry) }
#
# Iteration 172: Resolving
#    { Alive(x), ~Alive(x) }
#    { ~Alive(x), ~Eats(x,Peanuts) }
#   => { ~Alive(x), ~Eats(x,Peanuts) }
#
# Iteration 173: Resolving
#    { Alive(x), ~Alive(x) }
#    { Alive(x), Killed(x) }
#   => { Alive(x), Killed(x) }
#
# Iteration 174: Resolving
#    { Alive(x), ~Alive(x) }
#    { Alive(Anil) }
#   => { Alive(Anil) }
#
# Iteration 175: Resolving
#    { Alive(x), ~Alive(x) }
#    { Alive(x), ~Alive(x) }
#   => { Alive(x), ~Alive(x) }
#
# Iteration 176: Resolving
#    { Alive(x), ~Alive(x) }
#    { Alive(x), ~Alive(x) }
#   => { Alive(x), ~Alive(x) }
#
# Iteration 177: Resolving
#    { Alive(x), ~Alive(x) }
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#   => { ~Eats(x,y), ~Alive(x), Food(y) }
#
# Iteration 178: Resolving
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#    { Killed(x), ~Killed(x) }
#   => { Food(y), ~Eats(Anil,y), Killed(Harry) }
#
# Iteration 179: Resolving
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#    { ~Food(Peanuts) }
#   => { ~Eats(Anil,Peanuts), Killed(Harry) }
#
# Iteration 180: Resolving
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#    { ~Alive(x), ~Killed(x) }
#   => { ~Alive(Harry), Food(y), ~Eats(Anil,y) }
#
# Iteration 181: Resolving
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#    { Killed(x), ~Killed(x) }
#   => { Food(y), ~Eats(Anil,y), Killed(Harry) }
#
# Iteration 182: Resolving
#    { Food(y), ~Eats(Anil,y), Killed(Harry) }
#    { ~Food(Peanuts) }
#   => { ~Eats(Anil,Peanuts), Killed(Harry) }
#
# Iteration 183: Resolving
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#    { Eats(Harry,Peanuts) }
#   => { Food(Peanuts), ~Alive(Harry) }
#
# Iteration 184: Resolving
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#    { ~Food(Peanuts) }
#   => { ~Alive(x), ~Eats(x,Peanuts) }
#
# Iteration 185: Resolving
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#    { Eats(Harry,Peanuts) }
#   => { Food(Peanuts), ~Alive(Harry) }
#
# Iteration 186: Resolving
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#    { Alive(x), Killed(x) }
#   => { ~Eats(x,y), Killed(x), Food(y) }
#
# Iteration 187: Resolving
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#    { Alive(Anil) }
#   => { Food(y), ~Eats(Anil,y) }
#
# Iteration 188: Resolving
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#    { Alive(x), ~Alive(x) }
#   => { ~Eats(x,y), ~Alive(x), Food(y) }
#
# Iteration 189: Resolving
#    { ~Eats(x,y), ~Alive(x), Food(y) }
#    { ~Food(Peanuts) }
#   => { ~Alive(x), ~Eats(x,Peanuts) }
#
# Iteration 190: Resolving
#    { ~Killed(Anil) }
#    { Killed(x), ~Killed(x) }
#   => { ~Killed(Anil) }
#
# Iteration 191: Resolving
#    { ~Killed(Anil) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { ~Eats(Anil,Anil), Likes(John,Anil) }
#
# Iteration 192: Resolving
#    { ~Killed(Anil) }
#    { Likes(John,Peanuts), Killed(Anil) }
#   => { Likes(John,Peanuts) }
#
# Iteration 193: Resolving
#    { ~Killed(Anil) }
#    { Food(Peanuts), Killed(Anil) }
#   => { Food(Peanuts) }
#
# Iteration 194: Resolving
#    { ~Killed(Anil) }
#    { Killed(x), ~Eats(x,Peanuts) }
#   => { ~Eats(Anil,Peanuts) }
#
# Iteration 195: Resolving
#    { ~Killed(Anil) }
#    { Killed(x), ~Killed(x) }
#   => { ~Killed(Anil) }
#
# Iteration 196: Resolving
#    { ~Killed(Anil) }
#    { Alive(x), Killed(x) }
#   => { Alive(Anil) }
#
# Iteration 197: Resolving
#    { ~Killed(Anil) }
#    { ~Eats(x,y), Killed(x), Food(y) }
#   => { Food(y), ~Eats(Anil,y) }
#
# Iteration 198: Resolving
#    { ~Killed(Anil) }
#    { ~Eats(y,y), Killed(y), Likes(John,y) }
#   => { ~Eats(Anil,Anil), Likes(John,Anil) }
#
# Iteration 199: Resolving
#    { ~Killed(Anil) }
#    { Killed(Anil) }
#   => {}
#
# ❌ Empty clause derived — PROOF COMPLETE!
# True

# %%
from copy import deepcopy

def negate_literal(lit):
    return lit[1:] if lit.startswith("¬") else "¬" + lit

def resolve(ci, cj):
    resolvents = []
    for li in ci:
        for lj in cj:
            if li == negate_literal(lj):
                new_clause = set(ci)
                new_clause.remove(li)
                new_clause.update([x for x in cj if x != lj])
                resolvents.append(frozenset(new_clause))
    return resolvents

def resolution(kb, query):
    clauses = set(kb)
    clauses.add(frozenset([negate_literal(query)]))

    print("Initial Clauses:")
    for c in clauses:
        print(" ", c)
    print("\nResolution Steps:\n")

    new = set()
    iteration = 1

    while True:
        pairs = [(ci, cj) for ci in clauses for cj in clauses if ci != cj]

        for (ci, cj) in pairs:
            resolvents = resolve(ci, cj)
            for r in resolvents:
                if len(r) == 0:
                    print(f"Iteration {iteration}: Derived empty clause → CONTRADICTION")
                    return True
                if r not in clauses:
                    print(f"Iteration {iteration}: Resolving\n  {ci}\n  {cj}\n  => {r}\n")
                    new.add(r)
                    if iteration > 6:     # keep output small
                        return False
                    iteration += 1

        if new.issubset(clauses):
            return False
        clauses |= new

# --------------------- KB in CNF --------------------------

KB = {
    frozenset(["¬Food(x)", "Likes(John,x)"]),
    frozenset(["Food(Apple)"]),
    frozenset(["Food(Vegetables)"]),
    frozenset(["¬Eats(a,b)", "¬Alive(a)", "Food(b)"]),
    frozenset(["Eats(Anil,Peanuts)"]),
    frozenset(["Alive(Anil)"]),
    frozenset(["¬Eats(Anil,x)", "Eats(Harry,x)"]),
    frozenset(["¬Alive(a)", "¬Killed(a)"]),
    frozenset(["Killed(a)", "Alive(a)"])
}

query = "Likes(John,Peanuts)"

result = resolution(KB, query)

if result:
    print("\nConclusion: Likes(John, Peanuts) is TRUE by resolution.")
else:
    print("\nCould not derive contradiction. Query not proven.")
# Out:
# Initial Clauses:
#   frozenset({'¬Eats(a,b)', '¬Alive(a)', 'Food(b)'})
#   frozenset({'Eats(Harry,x)', '¬Eats(Anil,x)'})
#   frozenset({'Likes(John,x)', '¬Food(x)'})
#   frozenset({'Eats(Anil,Peanuts)'})
#   frozenset({'Alive(a)', 'Killed(a)'})
#   frozenset({'Food(Vegetables)'})
#   frozenset({'Food(Apple)'})
#   frozenset({'Alive(Anil)'})
#   frozenset({'¬Likes(John,Peanuts)'})
#   frozenset({'¬Alive(a)', '¬Killed(a)'})
#
# Resolution Steps:
#
# Iteration 1: Resolving
#   frozenset({'¬Eats(a,b)', '¬Alive(a)', 'Food(b)'})
#   frozenset({'Alive(a)', 'Killed(a)'})
#   => frozenset({'¬Eats(a,b)', 'Food(b)', 'Killed(a)'})
#
# Iteration 2: Resolving
#   frozenset({'Alive(a)', 'Killed(a)'})
#   frozenset({'¬Eats(a,b)', '¬Alive(a)', 'Food(b)'})
#   => frozenset({'¬Eats(a,b)', 'Food(b)', 'Killed(a)'})
#
# Iteration 3: Resolving
#   frozenset({'Alive(a)', 'Killed(a)'})
#   frozenset({'¬Alive(a)', '¬Killed(a)'})
#   => frozenset({'Killed(a)', '¬Killed(a)'})
#
# Iteration 4: Resolving
#   frozenset({'Alive(a)', 'Killed(a)'})
#   frozenset({'¬Alive(a)', '¬Killed(a)'})
#   => frozenset({'¬Alive(a)', 'Alive(a)'})
#
# Iteration 5: Resolving
#   frozenset({'¬Alive(a)', '¬Killed(a)'})
#   frozenset({'Alive(a)', 'Killed(a)'})
#   => frozenset({'Killed(a)', '¬Killed(a)'})
#
# Iteration 6: Resolving
#   frozenset({'¬Alive(a)', '¬Killed(a)'})
#   frozenset({'Alive(a)', 'Killed(a)'})
#   => frozenset({'¬Alive(a)', 'Alive(a)'})
#
#
# Could not derive contradiction. Query not proven.

# %%
# Resolution prover customized for the "John likes peanuts" proof.
# Outputs steps exactly like manual classroom resolution.

def substitute(term, subs):
    if term in subs:
        return subs[term]
    return term

def apply_subs(clause, subs):
    new_clause = []
    for lit in clause:
        pred, args = lit
        new_args = tuple(substitute(a, subs) for a in args)
        new_clause.append((pred, new_args))
    return new_clause

def negate(pred):
    return pred[1:] if pred.startswith("¬") else "¬" + pred

def resolve(c1, c2):
    """Try to resolve c1 and c2. Return (resolvent, substitutions, pivot) or None."""
    for lit1 in c1:
        pred1, args1 = lit1
        for lit2 in c2:
            pred2, args2 = lit2
            if pred1 == negate(pred2):
                subs = {}
                ok = True
                for a, b in zip(args1, args2):
                    if a.startswith("?"):
                        subs[a] = b
                    elif b.startswith("?"):
                        subs[b] = a
                    elif a != b:
                        ok = False
                        break
                if not ok:
                    continue
                c1_new = apply_subs([x for x in c1 if x != lit1], subs)
                c2_new = apply_subs([x for x in c2 if x != lit2], subs)
                resolvent = c1_new + c2_new
                return resolvent, subs, (lit1, lit2)
    return None

# ----------------------- CLAUSES (in literal form) ----------------------------
KB = [
    # 1. ¬food(x) ∨ likes(John,x)
    [("¬food", ("?x",)), ("likes", ("John","?x"))],

    # 2. food(Apple)
    [("food", ("Apple",))],

    # 3. food(Vegetables)
    [("food", ("Vegetables",))],

    # 4. ¬eats(y,z) ∨ killed(y) ∨ food(z)
    [("¬eats", ("?y","?z")), ("killed", ("?y",)), ("food", ("?z",))],

    # 5. eats(Anil,Peanuts)
    [("eats", ("Anil","Peanuts"))],

    # 6. alive(Anil)
    [("alive", ("Anil",))],

    # 7. ¬eats(Anil,w) ∨ eats(Harry,w)
    [("¬eats", ("Anil","?w")), ("eats", ("Harry","?w"))],

    # 8. killed(g) ∨ alive(g)
    [("killed", ("?g",)), ("alive", ("?g",))],

    # 9. ¬alive(k) ∨ ¬killed(k)
    [("¬alive", ("?k",)), ("¬killed", ("?k",))]
]

# Negated Query: ¬likes(John,Peanuts)
query = [("¬likes", ("John","Peanuts"))]
clauses = KB + [query]

# ------------------------- RESOLUTION LOOP ---------------------------
print("Resolution Proof:\n")

used_pairs = set()
step = 1

while True:
    found = False

    for i in range(len(clauses)):
        for j in range(i+1, len(clauses)):
            if (i, j) in used_pairs:
                continue
            used_pairs.add((i, j))

            res = resolve(clauses[i], clauses[j])
            if res:
                resolvent, subs, pivot = res
                print(f"Step {step}: Resolve")
                print("   ", clauses[i])
                print("   ", clauses[j])
                print("   Substitution:", subs)
                print("   Resolvent:", resolvent)
                print()

                if resolvent == []:
                    print("Empty clause {} derived → CONTRADICTION.\n")
                    print("Therefore: likes(John, Peanuts) is TRUE.")
                    raise SystemExit()

                clauses.append(resolvent)
                step += 1
                found = True
                break
        if found:
            break

    if not found:
        print("\nNo more resolutions — proof incomplete.")
        break
# Out:
# Resolution Proof:
#
# Step 1: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('food', ('Apple',))]
#    Substitution: {'?x': 'Apple'}
#    Resolvent: [('likes', ('John', 'Apple'))]
#
# Step 2: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('food', ('Vegetables',))]
#    Substitution: {'?x': 'Vegetables'}
#    Resolvent: [('likes', ('John', 'Vegetables'))]
#
# Step 3: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('¬eats', ('?y', '?z')), ('killed', ('?y',)), ('food', ('?z',))]
#    Substitution: {'?x': '?z'}
#    Resolvent: [('likes', ('John', '?z')), ('¬eats', ('?y', '?z')), ('killed', ('?y',))]
#
# Step 4: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('¬likes', ('John', 'Peanuts'))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('¬food', ('Peanuts',))]
#
# Step 5: Resolve
#     [('¬eats', ('?y', '?z')), ('killed', ('?y',)), ('food', ('?z',))]
#     [('eats', ('Anil', 'Peanuts'))]
#    Substitution: {'?y': 'Anil', '?z': 'Peanuts'}
#    Resolvent: [('killed', ('Anil',)), ('food', ('Peanuts',))]
#
# Step 6: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Anil',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Anil',))]
#
# Step 7: Resolve
#     [('¬eats', ('?y', '?z')), ('killed', ('?y',)), ('food', ('?z',))]
#     [('¬eats', ('Anil', '?w')), ('eats', ('Harry', '?w'))]
#    Substitution: {'?y': 'Harry', '?z': '?w'}
#    Resolvent: [('killed', ('Harry',)), ('food', ('?w',)), ('¬eats', ('Anil', '?w'))]
#
# Step 8: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Harry',)), ('food', ('?w',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?x': '?w'}
#    Resolvent: [('likes', ('John', '?w')), ('killed', ('Harry',)), ('¬eats', ('Anil', '?w'))]
#
# Step 9: Resolve
#     [('¬eats', ('?y', '?z')), ('killed', ('?y',)), ('food', ('?z',))]
#     [('¬alive', ('?k',)), ('¬killed', ('?k',))]
#    Substitution: {'?y': '?k'}
#    Resolvent: [('¬eats', ('?k', '?z')), ('food', ('?z',)), ('¬alive', ('?k',))]
#
# Step 10: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('¬eats', ('?k', '?z')), ('food', ('?z',)), ('¬alive', ('?k',))]
#    Substitution: {'?x': '?z'}
#    Resolvent: [('likes', ('John', '?z')), ('¬eats', ('?k', '?z')), ('¬alive', ('?k',))]
#
# Step 11: Resolve
#     [('¬eats', ('?y', '?z')), ('killed', ('?y',)), ('food', ('?z',))]
#     [('¬food', ('Peanuts',))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('¬eats', ('?y', 'Peanuts')), ('killed', ('?y',))]
#
# Step 12: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', '?w')), ('eats', ('Harry', '?w'))]
#    Substitution: {'?w': 'Peanuts'}
#    Resolvent: [('eats', ('Harry', 'Peanuts'))]
#
# Step 13: Resolve
#     [('¬eats', ('?y', '?z')), ('killed', ('?y',)), ('food', ('?z',))]
#     [('eats', ('Harry', 'Peanuts'))]
#    Substitution: {'?y': 'Harry', '?z': 'Peanuts'}
#    Resolvent: [('killed', ('Harry',)), ('food', ('Peanuts',))]
#
# Step 14: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Harry',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 15: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?z')), ('¬eats', ('?y', '?z')), ('killed', ('?y',))]
#    Substitution: {'?y': 'Anil', '?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Anil',))]
#
# Step 16: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('killed', ('Harry',)), ('food', ('?w',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?w': 'Peanuts'}
#    Resolvent: [('killed', ('Harry',)), ('food', ('Peanuts',))]
#
# Step 17: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Harry',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 18: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?w')), ('killed', ('Harry',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?w': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 19: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('?k', '?z')), ('food', ('?z',)), ('¬alive', ('?k',))]
#    Substitution: {'?k': 'Anil', '?z': 'Peanuts'}
#    Resolvent: [('food', ('Peanuts',)), ('¬alive', ('Anil',))]
#
# Step 20: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('food', ('Peanuts',)), ('¬alive', ('Anil',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('¬alive', ('Anil',))]
#
# Step 21: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?z')), ('¬eats', ('?k', '?z')), ('¬alive', ('?k',))]
#    Substitution: {'?k': 'Anil', '?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('¬alive', ('Anil',))]
#
# Step 22: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('?y', 'Peanuts')), ('killed', ('?y',))]
#    Substitution: {'?y': 'Anil'}
#    Resolvent: [('killed', ('Anil',))]
#
# Step 23: Resolve
#     [('alive', ('Anil',))]
#     [('¬alive', ('?k',)), ('¬killed', ('?k',))]
#    Substitution: {'?k': 'Anil'}
#    Resolvent: [('¬killed', ('Anil',))]
#
# Step 24: Resolve
#     [('¬eats', ('?y', '?z')), ('killed', ('?y',)), ('food', ('?z',))]
#     [('¬killed', ('Anil',))]
#    Substitution: {'?y': 'Anil'}
#    Resolvent: [('¬eats', ('Anil', '?z')), ('food', ('?z',))]
#
# Step 25: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('¬eats', ('Anil', '?z')), ('food', ('?z',))]
#    Substitution: {'?x': '?z'}
#    Resolvent: [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z'))]
#
# Step 26: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', '?z')), ('food', ('?z',))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('food', ('Peanuts',))]
#
# Step 27: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 28: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z'))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 29: Resolve
#     [('alive', ('Anil',))]
#     [('¬eats', ('?k', '?z')), ('food', ('?z',)), ('¬alive', ('?k',))]
#    Substitution: {'?k': 'Anil'}
#    Resolvent: [('¬eats', ('Anil', '?z')), ('food', ('?z',))]
#
# Step 30: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('¬eats', ('Anil', '?z')), ('food', ('?z',))]
#    Substitution: {'?x': '?z'}
#    Resolvent: [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z'))]
#
# Step 31: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', '?z')), ('food', ('?z',))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('food', ('Peanuts',))]
#
# Step 32: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 33: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z'))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 34: Resolve
#     [('alive', ('Anil',))]
#     [('likes', ('John', '?z')), ('¬eats', ('?k', '?z')), ('¬alive', ('?k',))]
#    Substitution: {'?k': 'Anil'}
#    Resolvent: [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z'))]
#
# Step 35: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z'))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 36: Resolve
#     [('alive', ('Anil',))]
#     [('food', ('Peanuts',)), ('¬alive', ('Anil',))]
#    Substitution: {}
#    Resolvent: [('food', ('Peanuts',))]
#
# Step 37: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 38: Resolve
#     [('alive', ('Anil',))]
#     [('likes', ('John', 'Peanuts')), ('¬alive', ('Anil',))]
#    Substitution: {}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 39: Resolve
#     [('alive', ('Anil',))]
#     [('likes', ('John', 'Peanuts')), ('¬alive', ('Anil',))]
#    Substitution: {}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 40: Resolve
#     [('¬eats', ('Anil', '?w')), ('eats', ('Harry', '?w'))]
#     [('likes', ('John', '?z')), ('¬eats', ('?y', '?z')), ('killed', ('?y',))]
#    Substitution: {'?y': 'Harry', '?w': '?z'}
#    Resolvent: [('¬eats', ('Anil', '?z')), ('likes', ('John', '?z')), ('killed', ('Harry',))]
#
# Step 41: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', '?z')), ('likes', ('John', '?z')), ('killed', ('Harry',))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 42: Resolve
#     [('¬eats', ('Anil', '?w')), ('eats', ('Harry', '?w'))]
#     [('¬eats', ('?k', '?z')), ('food', ('?z',)), ('¬alive', ('?k',))]
#    Substitution: {'?k': 'Harry', '?w': '?z'}
#    Resolvent: [('¬eats', ('Anil', '?z')), ('food', ('?z',)), ('¬alive', ('Harry',))]
#
# Step 43: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('¬eats', ('Anil', '?z')), ('food', ('?z',)), ('¬alive', ('Harry',))]
#    Substitution: {'?x': '?z'}
#    Resolvent: [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z')), ('¬alive', ('Harry',))]
#
# Step 44: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', '?z')), ('food', ('?z',)), ('¬alive', ('Harry',))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('food', ('Peanuts',)), ('¬alive', ('Harry',))]
#
# Step 45: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('food', ('Peanuts',)), ('¬alive', ('Harry',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('¬alive', ('Harry',))]
#
# Step 46: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z')), ('¬alive', ('Harry',))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('¬alive', ('Harry',))]
#
# Step 47: Resolve
#     [('¬eats', ('Anil', '?w')), ('eats', ('Harry', '?w'))]
#     [('likes', ('John', '?z')), ('¬eats', ('?k', '?z')), ('¬alive', ('?k',))]
#    Substitution: {'?k': 'Harry', '?w': '?z'}
#    Resolvent: [('¬eats', ('Anil', '?z')), ('likes', ('John', '?z')), ('¬alive', ('Harry',))]
#
# Step 48: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', '?z')), ('likes', ('John', '?z')), ('¬alive', ('Harry',))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('¬alive', ('Harry',))]
#
# Step 49: Resolve
#     [('¬eats', ('Anil', '?w')), ('eats', ('Harry', '?w'))]
#     [('¬eats', ('?y', 'Peanuts')), ('killed', ('?y',))]
#    Substitution: {'?y': 'Harry', '?w': 'Peanuts'}
#    Resolvent: [('¬eats', ('Anil', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 50: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', 'Peanuts')), ('killed', ('Harry',))]
#    Substitution: {}
#    Resolvent: [('killed', ('Harry',))]
#
# Step 51: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬alive', ('?k',)), ('¬killed', ('?k',))]
#    Substitution: {'?g': '?k'}
#    Resolvent: [('alive', ('?k',)), ('¬alive', ('?k',))]
#
# Step 52: Resolve
#     [('alive', ('Anil',))]
#     [('alive', ('?k',)), ('¬alive', ('?k',))]
#    Substitution: {'?k': 'Anil'}
#    Resolvent: [('alive', ('Anil',))]
#
# Step 53: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬eats', ('?k', '?z')), ('food', ('?z',)), ('¬alive', ('?k',))]
#    Substitution: {'?g': '?k'}
#    Resolvent: [('killed', ('?k',)), ('¬eats', ('?k', '?z')), ('food', ('?z',))]
#
# Step 54: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('?k',)), ('¬eats', ('?k', '?z')), ('food', ('?z',))]
#    Substitution: {'?x': '?z'}
#    Resolvent: [('likes', ('John', '?z')), ('killed', ('?k',)), ('¬eats', ('?k', '?z'))]
#
# Step 55: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('killed', ('?k',)), ('¬eats', ('?k', '?z')), ('food', ('?z',))]
#    Substitution: {'?k': 'Anil', '?z': 'Peanuts'}
#    Resolvent: [('killed', ('Anil',)), ('food', ('Peanuts',))]
#
# Step 56: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Anil',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Anil',))]
#
# Step 57: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?z')), ('killed', ('?k',)), ('¬eats', ('?k', '?z'))]
#    Substitution: {'?k': 'Anil', '?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Anil',))]
#
# Step 58: Resolve
#     [('¬eats', ('Anil', '?w')), ('eats', ('Harry', '?w'))]
#     [('killed', ('?k',)), ('¬eats', ('?k', '?z')), ('food', ('?z',))]
#    Substitution: {'?k': 'Harry', '?w': '?z'}
#    Resolvent: [('¬eats', ('Anil', '?z')), ('killed', ('Harry',)), ('food', ('?z',))]
#
# Step 59: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('¬eats', ('Anil', '?z')), ('killed', ('Harry',)), ('food', ('?z',))]
#    Substitution: {'?x': '?z'}
#    Resolvent: [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z')), ('killed', ('Harry',))]
#
# Step 60: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', '?z')), ('killed', ('Harry',)), ('food', ('?z',))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('killed', ('Harry',)), ('food', ('Peanuts',))]
#
# Step 61: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Harry',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 62: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z')), ('killed', ('Harry',))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 63: Resolve
#     [('¬eats', ('Anil', '?w')), ('eats', ('Harry', '?w'))]
#     [('likes', ('John', '?z')), ('killed', ('?k',)), ('¬eats', ('?k', '?z'))]
#    Substitution: {'?k': 'Harry', '?w': '?z'}
#    Resolvent: [('¬eats', ('Anil', '?z')), ('likes', ('John', '?z')), ('killed', ('Harry',))]
#
# Step 64: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', '?z')), ('likes', ('John', '?z')), ('killed', ('Harry',))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 65: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('likes', ('John', '?z')), ('¬eats', ('?k', '?z')), ('¬alive', ('?k',))]
#    Substitution: {'?g': '?k'}
#    Resolvent: [('killed', ('?k',)), ('likes', ('John', '?z')), ('¬eats', ('?k', '?z'))]
#
# Step 66: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('killed', ('?k',)), ('likes', ('John', '?z')), ('¬eats', ('?k', '?z'))]
#    Substitution: {'?k': 'Anil', '?z': 'Peanuts'}
#    Resolvent: [('killed', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#
# Step 67: Resolve
#     [('¬eats', ('Anil', '?w')), ('eats', ('Harry', '?w'))]
#     [('killed', ('?k',)), ('likes', ('John', '?z')), ('¬eats', ('?k', '?z'))]
#    Substitution: {'?k': 'Harry', '?w': '?z'}
#    Resolvent: [('¬eats', ('Anil', '?z')), ('killed', ('Harry',)), ('likes', ('John', '?z'))]
#
# Step 68: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', '?z')), ('killed', ('Harry',)), ('likes', ('John', '?z'))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 69: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('food', ('Peanuts',)), ('¬alive', ('Anil',))]
#    Substitution: {'?g': 'Anil'}
#    Resolvent: [('killed', ('Anil',)), ('food', ('Peanuts',))]
#
# Step 70: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Anil',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Anil',))]
#
# Step 71: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('likes', ('John', 'Peanuts')), ('¬alive', ('Anil',))]
#    Substitution: {'?g': 'Anil'}
#    Resolvent: [('killed', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#
# Step 72: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('likes', ('John', 'Peanuts')), ('¬alive', ('Anil',))]
#    Substitution: {'?g': 'Anil'}
#    Resolvent: [('killed', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#
# Step 73: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬killed', ('Anil',))]
#    Substitution: {'?g': 'Anil'}
#    Resolvent: [('alive', ('Anil',))]
#
# Step 74: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬eats', ('Anil', '?z')), ('food', ('?z',)), ('¬alive', ('Harry',))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('¬eats', ('Anil', '?z')), ('food', ('?z',))]
#
# Step 75: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Harry',)), ('¬eats', ('Anil', '?z')), ('food', ('?z',))]
#    Substitution: {'?x': '?z'}
#    Resolvent: [('likes', ('John', '?z')), ('killed', ('Harry',)), ('¬eats', ('Anil', '?z'))]
#
# Step 76: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('killed', ('Harry',)), ('¬eats', ('Anil', '?z')), ('food', ('?z',))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('killed', ('Harry',)), ('food', ('Peanuts',))]
#
# Step 77: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Harry',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 78: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?z')), ('killed', ('Harry',)), ('¬eats', ('Anil', '?z'))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 79: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z')), ('¬alive', ('Harry',))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', '?z')), ('¬eats', ('Anil', '?z'))]
#
# Step 80: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('killed', ('Harry',)), ('likes', ('John', '?z')), ('¬eats', ('Anil', '?z'))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 81: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('food', ('Peanuts',)), ('¬alive', ('Harry',))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('food', ('Peanuts',))]
#
# Step 82: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Harry',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 83: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('likes', ('John', 'Peanuts')), ('¬alive', ('Harry',))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 84: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('likes', ('John', 'Peanuts')), ('¬alive', ('Harry',))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 85: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬eats', ('Anil', '?z')), ('likes', ('John', '?z')), ('¬alive', ('Harry',))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('¬eats', ('Anil', '?z')), ('likes', ('John', '?z'))]
#
# Step 86: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('killed', ('Harry',)), ('¬eats', ('Anil', '?z')), ('likes', ('John', '?z'))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 87: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('likes', ('John', 'Peanuts')), ('¬alive', ('Harry',))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 88: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('alive', ('?k',)), ('¬alive', ('?k',))]
#    Substitution: {'?g': '?k'}
#    Resolvent: [('killed', ('?k',)), ('alive', ('?k',))]
#
# Step 89: Resolve
#     [('¬alive', ('?k',)), ('¬killed', ('?k',))]
#     [('likes', ('John', '?z')), ('¬eats', ('?y', '?z')), ('killed', ('?y',))]
#    Substitution: {'?k': '?y'}
#    Resolvent: [('¬alive', ('?y',)), ('likes', ('John', '?z')), ('¬eats', ('?y', '?z'))]
#
# Step 90: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬alive', ('?y',)), ('likes', ('John', '?z')), ('¬eats', ('?y', '?z'))]
#    Substitution: {'?y': 'Anil', '?z': 'Peanuts'}
#    Resolvent: [('¬alive', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#
# Step 91: Resolve
#     [('alive', ('Anil',))]
#     [('¬alive', ('?y',)), ('likes', ('John', '?z')), ('¬eats', ('?y', '?z'))]
#    Substitution: {'?y': 'Anil'}
#    Resolvent: [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z'))]
#
# Step 92: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?z')), ('¬eats', ('Anil', '?z'))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 93: Resolve
#     [('alive', ('Anil',))]
#     [('¬alive', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#    Substitution: {}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 94: Resolve
#     [('¬eats', ('Anil', '?w')), ('eats', ('Harry', '?w'))]
#     [('¬alive', ('?y',)), ('likes', ('John', '?z')), ('¬eats', ('?y', '?z'))]
#    Substitution: {'?y': 'Harry', '?w': '?z'}
#    Resolvent: [('¬eats', ('Anil', '?z')), ('¬alive', ('Harry',)), ('likes', ('John', '?z'))]
#
# Step 95: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', '?z')), ('¬alive', ('Harry',)), ('likes', ('John', '?z'))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('¬alive', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 96: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬alive', ('?y',)), ('likes', ('John', '?z')), ('¬eats', ('?y', '?z'))]
#    Substitution: {'?g': '?y'}
#    Resolvent: [('killed', ('?y',)), ('likes', ('John', '?z')), ('¬eats', ('?y', '?z'))]
#
# Step 97: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('killed', ('?y',)), ('likes', ('John', '?z')), ('¬eats', ('?y', '?z'))]
#    Substitution: {'?y': 'Anil', '?z': 'Peanuts'}
#    Resolvent: [('killed', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#
# Step 98: Resolve
#     [('¬eats', ('Anil', '?w')), ('eats', ('Harry', '?w'))]
#     [('killed', ('?y',)), ('likes', ('John', '?z')), ('¬eats', ('?y', '?z'))]
#    Substitution: {'?y': 'Harry', '?w': '?z'}
#    Resolvent: [('¬eats', ('Anil', '?z')), ('killed', ('Harry',)), ('likes', ('John', '?z'))]
#
# Step 99: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', '?z')), ('killed', ('Harry',)), ('likes', ('John', '?z'))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 100: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬alive', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#    Substitution: {'?g': 'Anil'}
#    Resolvent: [('killed', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#
# Step 101: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬eats', ('Anil', '?z')), ('¬alive', ('Harry',)), ('likes', ('John', '?z'))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('¬eats', ('Anil', '?z')), ('likes', ('John', '?z'))]
#
# Step 102: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('killed', ('Harry',)), ('¬eats', ('Anil', '?z')), ('likes', ('John', '?z'))]
#    Substitution: {'?z': 'Peanuts'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 103: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬alive', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 104: Resolve
#     [('¬alive', ('?k',)), ('¬killed', ('?k',))]
#     [('killed', ('Anil',)), ('food', ('Peanuts',))]
#    Substitution: {'?k': 'Anil'}
#    Resolvent: [('¬alive', ('Anil',)), ('food', ('Peanuts',))]
#
# Step 105: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('¬alive', ('Anil',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('¬alive', ('Anil',))]
#
# Step 106: Resolve
#     [('alive', ('Anil',))]
#     [('¬alive', ('Anil',)), ('food', ('Peanuts',))]
#    Substitution: {}
#    Resolvent: [('food', ('Peanuts',))]
#
# Step 107: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 108: Resolve
#     [('alive', ('Anil',))]
#     [('likes', ('John', 'Peanuts')), ('¬alive', ('Anil',))]
#    Substitution: {}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 109: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬alive', ('Anil',)), ('food', ('Peanuts',))]
#    Substitution: {'?g': 'Anil'}
#    Resolvent: [('killed', ('Anil',)), ('food', ('Peanuts',))]
#
# Step 110: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Anil',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Anil',))]
#
# Step 111: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('likes', ('John', 'Peanuts')), ('¬alive', ('Anil',))]
#    Substitution: {'?g': 'Anil'}
#    Resolvent: [('killed', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#
# Step 112: Resolve
#     [('¬alive', ('?k',)), ('¬killed', ('?k',))]
#     [('likes', ('John', 'Peanuts')), ('killed', ('Anil',))]
#    Substitution: {'?k': 'Anil'}
#    Resolvent: [('¬alive', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#
# Step 113: Resolve
#     [('alive', ('Anil',))]
#     [('¬alive', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#    Substitution: {}
#    Resolvent: [('likes', ('John', 'Peanuts'))]
#
# Step 114: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬alive', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#    Substitution: {'?g': 'Anil'}
#    Resolvent: [('killed', ('Anil',)), ('likes', ('John', 'Peanuts'))]
#
# Step 115: Resolve
#     [('¬alive', ('?k',)), ('¬killed', ('?k',))]
#     [('killed', ('Harry',)), ('food', ('?w',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?k': 'Harry'}
#    Resolvent: [('¬alive', ('Harry',)), ('food', ('?w',)), ('¬eats', ('Anil', '?w'))]
#
# Step 116: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('¬alive', ('Harry',)), ('food', ('?w',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?x': '?w'}
#    Resolvent: [('likes', ('John', '?w')), ('¬alive', ('Harry',)), ('¬eats', ('Anil', '?w'))]
#
# Step 117: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬alive', ('Harry',)), ('food', ('?w',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?w': 'Peanuts'}
#    Resolvent: [('¬alive', ('Harry',)), ('food', ('Peanuts',))]
#
# Step 118: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('¬alive', ('Harry',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('¬alive', ('Harry',))]
#
# Step 119: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?w')), ('¬alive', ('Harry',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?w': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('¬alive', ('Harry',))]
#
# Step 120: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬alive', ('Harry',)), ('food', ('?w',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('food', ('?w',)), ('¬eats', ('Anil', '?w'))]
#
# Step 121: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Harry',)), ('food', ('?w',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?x': '?w'}
#    Resolvent: [('likes', ('John', '?w')), ('killed', ('Harry',)), ('¬eats', ('Anil', '?w'))]
#
# Step 122: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('killed', ('Harry',)), ('food', ('?w',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?w': 'Peanuts'}
#    Resolvent: [('killed', ('Harry',)), ('food', ('Peanuts',))]
#
# Step 123: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Harry',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 124: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('likes', ('John', '?w')), ('killed', ('Harry',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?w': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 125: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('likes', ('John', '?w')), ('¬alive', ('Harry',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', '?w')), ('¬eats', ('Anil', '?w'))]
#
# Step 126: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('killed', ('Harry',)), ('likes', ('John', '?w')), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?w': 'Peanuts'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 127: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬alive', ('Harry',)), ('food', ('Peanuts',))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('food', ('Peanuts',))]
#
# Step 128: Resolve
#     [('¬food', ('?x',)), ('likes', ('John', '?x'))]
#     [('killed', ('Harry',)), ('food', ('Peanuts',))]
#    Substitution: {'?x': 'Peanuts'}
#    Resolvent: [('likes', ('John', 'Peanuts')), ('killed', ('Harry',))]
#
# Step 129: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('likes', ('John', 'Peanuts')), ('¬alive', ('Harry',))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 130: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('likes', ('John', 'Peanuts')), ('¬alive', ('Harry',))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 131: Resolve
#     [('¬alive', ('?k',)), ('¬killed', ('?k',))]
#     [('likes', ('John', '?w')), ('killed', ('Harry',)), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?k': 'Harry'}
#    Resolvent: [('¬alive', ('Harry',)), ('likes', ('John', '?w')), ('¬eats', ('Anil', '?w'))]
#
# Step 132: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬alive', ('Harry',)), ('likes', ('John', '?w')), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?w': 'Peanuts'}
#    Resolvent: [('¬alive', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 133: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬alive', ('Harry',)), ('likes', ('John', '?w')), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', '?w')), ('¬eats', ('Anil', '?w'))]
#
# Step 134: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('killed', ('Harry',)), ('likes', ('John', '?w')), ('¬eats', ('Anil', '?w'))]
#    Substitution: {'?w': 'Peanuts'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 135: Resolve
#     [('killed', ('?g',)), ('alive', ('?g',))]
#     [('¬alive', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#    Substitution: {'?g': 'Harry'}
#    Resolvent: [('killed', ('Harry',)), ('likes', ('John', 'Peanuts'))]
#
# Step 136: Resolve
#     [('¬alive', ('?k',)), ('¬killed', ('?k',))]
#     [('¬eats', ('?y', 'Peanuts')), ('killed', ('?y',))]
#    Substitution: {'?k': '?y'}
#    Resolvent: [('¬alive', ('?y',)), ('¬eats', ('?y', 'Peanuts'))]
#
# Step 137: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬alive', ('?y',)), ('¬eats', ('?y', 'Peanuts'))]
#    Substitution: {'?y': 'Anil'}
#    Resolvent: [('¬alive', ('Anil',))]
#
# Step 138: Resolve
#     [('alive', ('Anil',))]
#     [('¬alive', ('?y',)), ('¬eats', ('?y', 'Peanuts'))]
#    Substitution: {'?y': 'Anil'}
#    Resolvent: [('¬eats', ('Anil', 'Peanuts'))]
#
# Step 139: Resolve
#     [('eats', ('Anil', 'Peanuts'))]
#     [('¬eats', ('Anil', 'Peanuts'))]
#    Substitution: {}
#    Resolvent: []
#
# Empty clause {} derived → CONTRADICTION.
#
# Therefore: likes(John, Peanuts) is TRUE.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
from itertools import combinations

# -------------------- Unification ----------------------------

def is_var(x):
    return isinstance(x, str) and x[0].islower()

def unify(x, y, subst):
    if subst is False:
        return False
    if x == y:
        return subst
    if is_var(x):
        return unify_var(x, y, subst)
    if is_var(y):
        return unify_var(y, x, subst)
    if isinstance(x, tuple) and isinstance(y, tuple):
        if len(x) != len(y):
            return False
        for a, b in zip(x, y):
            subst = unify(a, b, subst)
        return subst
    return False

def unify_var(var, x, subst):
    if var in subst:
        return unify(subst[var], x, subst)
    if occurs(var, x, subst):
        return False
    subst[var] = x
    return subst

def occurs(var, x, subst):
    if var == x:
        return True
    if isinstance(x, tuple):
        return any(occurs(var, t, subst) for t in x)
    if x in subst:
        return occurs(var, subst[x], subst)
    return False

# -------------------- Substitution ---------------------------

def apply_subst(term, subst):
    pred, args, sign = term
    new_args = []
    for a in args:
        if isinstance(a, str):
            new_args.append(subst.get(a, a))
        else:
            new_args.append(apply_subst(a, subst))
    return (pred, tuple(new_args), sign)

def apply_subst_clause(clause, subst):
    return [apply_subst(lit, subst) for lit in clause]

# -------------------- Resolution -----------------------------

def resolve(c1, c2):
    resolvents = []
    for i, lit1 in enumerate(c1):
        for j, lit2 in enumerate(c2):

            # Complementary literals?
            if lit1[0] == lit2[0] and lit1[2] != lit2[2]:

                subst = unify(lit1[1], lit2[1], {})
                if subst is False:
                    continue

                new_clause = (
                    c1[:i] + c1[i+1:] +
                    c2[:j] + c2[j+1:]
                )
                new_clause = apply_subst_clause(new_clause, subst)
                new_clause = list(set(new_clause))  # remove duplicates

                resolvents.append(new_clause)
    return resolvents

# -------------------------------------------------------------
#    MINIMAL KNOWLEDGE BASE (3 clauses)
# -------------------------------------------------------------

KB = [

    # John likes any food
    [("Food", ("x",), False), ("Likes", ("John", "x"), True)],

    # Anil eats peanuts
    [("Eats", ("Anil", "Peanuts"), True)],

    # Anything Anil eats is food
    [("Eats", ("Anil", "y"), False), ("Food", ("y",), True)],
]

# Negated goal
goal = [("Likes", ("John", "Peanuts"), False)]

clauses = KB + [goal]

# -------------------------------------------------------------
#   Resolution Loop
# -------------------------------------------------------------

def resolution(clauses):
    new = []

    while True:
        pairs = list(combinations(clauses, 2))

        for (c1, c2) in pairs:
            resolvents = resolve(c1, c2)

            for r in resolvents:
                print("Resolvent:", r)

                if r == []:
                    print("\n✓ Empty clause derived!")
                    print("✓ Therefore: John likes peanuts.")
                    return True

                new.append(r)

        if all(r in clauses for r in new):
            print("\nNo new clauses. Cannot prove.")
            return False

        for r in new:
            if r not in clauses:
                clauses.append(r)

print("RUNNING RESOLUTION...\n")
resolution(clauses)
# Out:
# RUNNING RESOLUTION...
#
# Resolvent: [('Likes', ('John', 'y'), True), ('Eats', ('Anil', 'y'), False)]
# Resolvent: [('Food', ('Peanuts',), False)]
# Resolvent: [('Food', ('Peanuts',), True)]
# Resolvent: [('Likes', ('John', 'y'), True), ('Eats', ('Anil', 'y'), False)]
# Resolvent: [('Food', ('Peanuts',), False)]
# Resolvent: [('Likes', ('John', 'Peanuts'), True)]
# Resolvent: [('Food', ('Peanuts',), True)]
# Resolvent: [('Likes', ('John', 'Peanuts'), True)]
# Resolvent: [('Eats', ('Anil', 'Peanuts'), False)]
# Resolvent: [('Eats', ('Anil', 'Peanuts'), False)]
# Resolvent: []
#
# ✓ Empty clause derived!
# ✓ Therefore: John likes peanuts.
# True
